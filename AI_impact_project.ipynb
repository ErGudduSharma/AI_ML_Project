# %% [markdown]
# # The Global AI Content Impact Dataset provides a comprehensive overview of how artificial intelligence (AI) is transforming industries, countries, and global markets.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"/content/Global_AI_Content_Impact_Dataset.csv")
df.head(3)
# Out:
#        Country  Year    Industry  AI Adoption Rate (%)  \
# 0  South Korea  2022       Media                 44.29
# 1        China  2025       Legal                 34.75
# 2          USA  2022  Automotive                 81.06
#
#    AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                       33.09                   16.77
# 1                                       66.74                   46.89
# 2                                       96.13                   10.66
#
#    Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                           46.12                            74.79
# 1                           52.46                            26.17
# 2                           45.60                            39.66
#
#   Top AI Tools Used Regulation Status  Consumer Trust in AI (%)  \
# 0              Bard            Strict                     40.77
# ...

# %%
df.isnull().sum()
# Out:
# Country                                       0
# Year                                          0
# Industry                                      0
# AI Adoption Rate (%)                          0
# AI-Generated Content Volume (TBs per year)    0
# Job Loss Due to AI (%)                        0
# Revenue Increase Due to AI (%)                0
# Human-AI Collaboration Rate (%)               0
# Top AI Tools Used                             0
# Regulation Status                             0
# Consumer Trust in AI (%)                      0
# Market Share of AI Companies (%)              0
# dtype: int64

# %%
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default='plotly_white'
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Industry', 'AI Adoption Rate (%)',
#        'AI-Generated Content Volume (TBs per year)', 'Job Loss Due to AI (%)',
#        'Revenue Increase Due to AI (%)', 'Human-AI Collaboration Rate (%)',
#        'Top AI Tools Used', 'Regulation Status', 'Consumer Trust in AI (%)',
#        'Market Share of AI Companies (%)'],
#       dtype='object')

# %% [markdown]
# # Job loss data in different coutries

# %%
Job_Loss_data=df.groupby('Country')['Job Loss Due to AI (%)'].sum().reset_index()
fig=go.Figure(go.Bar(x=Job_Loss_data['Country'],
                    y=Job_Loss_data['Job Loss Due to AI (%)']))
fig.update_layout(title='Job loss data in different coutries',
                 xaxis_title='Country',
                 yaxis_title='Job Loss Due to AI (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Above this chart we analysis that France is the highest job loss due to AI and china is the second highest country  and least job loss country is Australia. AI adoption leads to varied job displacement across regions

# %% [markdown]
# # Top AI tools used by customer trust

# %%
total_revenue=df.groupby('Top AI Tools Used')['Consumer Trust in AI (%)'].size().reset_index()
fig=go.Figure(go.Bar(x=total_revenue['Top AI Tools Used'],
                    y=total_revenue['Consumer Trust in AI (%)']))
fig.update_layout(title='Top AI tools used by customer',
                 xaxis_title='Top AI Tools Used',
                 yaxis_title='Consumer Trust in AI (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # This bar chart shows the most commonly used AI tools based on customer usage data.We see Midjourney AI tools highly used by customer. Bard,Synthesia AI tools are least used.AI tools that are user-friendly, reliable, and versatile are adopted more frequently used.

# %% [markdown]
# # Rules and Regulations in country

# %%
Regulation_data = df.groupby('Regulation Status').size().reset_index(name='Count')
pie_chart = px.pie(
    Regulation_data,
    values='Count',
    names='Regulation Status',
    title='Status',
    hole=0.5,
    color_discrete_sequence=px.colors.qualitative.Pastel)
pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Above this pie chart we analayis that rules and regulations for using AI are the moderate in mostly countries and Lenient and strict rules and regulations are equally in some countries.

# %% [markdown]
# # Top 5 countries AI adoption rate

# %%
top_countries = df.groupby("Country")["AI Adoption Rate (%)"].mean().head(5)
top_countries.plot(kind='bar', color='skyblue')
plt.title("Top 5 Countries by Average AI Adoption Rate")
plt.ylabel("AI Adoption Rate (%)")
plt.xlabel("Country")
plt.show()

# %% [markdown]
# ## This chart show France and Australia leads with the highest average AI adoption rate. These countries are at the forefront of AI integration, suggesting advanced infrastructure for AI-driven innovation.Further Germany, Canada, China are equally AI Adoption Rate.

# %% [markdown]
# # Revenue generated by different industries

# %%
Industry_year=df.groupby('Industry')['Revenue Increase Due to AI (%)'].mean().reset_index()
fig=go.Figure(go.Bar(x=Industry_year['Industry'],
                     y=Industry_year['Revenue Increase Due to AI (%)']))
fig.update_layout(title='Revenue percentage in industries',
                 xaxis_title='Industry',
                 yaxis_title='Revenue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Industries that are more data-intensive or customer-focused tend to benefit the most from AI in terms of revenue. So, Automotive Industry is the Highest and Gaming is the lowest Industry.

# %% [markdown]
# ### Market share of AI compaines in 2020-2025

# %%
Market_share=df.groupby('Year')['Market Share of AI Companies (%)'].size().reset_index()

Market_share_chart=px.bar(Market_share,x='Year',
                              y='Market Share of AI Companies (%)',
                              title='Market share by percentage ',
                             color='Year',)
Market_share_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## The chart likely shows a steady or sharp increase in average market share over recent years. 2020 is the highest market share growth and 2024 is the lowest market share growth.

# %% [markdown]
# # Revenue Increase in 2020-2025

# %%
revenue_year=df.groupby('Year')['Revenue Increase Due to AI (%)'].mean().reset_index()
fig=go.Figure(go.Bar(x=revenue_year['Year'],
                     y=revenue_year['Revenue Increase Due to AI (%)']))
fig.update_layout(title='Revenue increase in 2020-2025',
                 xaxis_title='Year',
                 yaxis_title='Revenue %')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## This graph shows how average revenue attributed to AI has changed year by year. we analysis that highest average increment of revenue in 2024 i.e (42%) and (33%) is the least in 2023 year.

# %% [markdown]
# # Summary

# %% [markdown]
# ### The analysis of the Dataset shows that AI is growing fast and becoming a major part of many industries. Companies are investing more in AI, and more tools are being developed for different needs.Overall, this dataset helps us understand how AI is changing our world.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     200 non-null    object
#  1   Year                                        200 non-null    int64
#  2   Industry                                    200 non-null    object
#  3   AI Adoption Rate (%)                        200 non-null    float64
#  4   AI-Generated Content Volume (TBs per year)  200 non-null    float64
#  5   Job Loss Due to AI (%)                      200 non-null    float64
#  6   Revenue Increase Due to AI (%)              200 non-null    float64
#  7   Human-AI Collaboration Rate (%)             200 non-null    float64
#  8   Top AI Tools Used                           200 non-null    object
# ...

# %%
df.describe()
# Out:
#               Year  AI Adoption Rate (%)  \
# count   200.000000            200.000000
# mean   2022.315000             54.265850
# std       1.825496             24.218067
# min    2020.000000             10.530000
# 25%    2021.000000             33.222500
# 50%    2022.000000             53.310000
# 75%    2024.000000             76.220000
# max    2025.000000             94.760000
#
#        AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# count                                   200.00000              200.000000
# mean                                     46.07260               25.788250
# std                                      29.16122               13.901105
# min                                       1.04000                0.090000
# 25%                                      20.32250               14.995000
# 50%                                      44.32000               25.735000
# ...

# %%
numeric_features = []
categorical_features = []

for col in df.columns:
  if df[col].dtypes == 'object':
    categorical_features.append(col)

  else:
    numeric_features.append(col)

print('numeric_features....', numeric_features)
print('cat_features....', categorical_features)
# Out:
# numeric_features.... ['Year', 'AI Adoption Rate (%)', 'AI-Generated Content Volume (TBs per year)', 'Job Loss Due to AI (%)', 'Revenue Increase Due to AI (%)', 'Human-AI Collaboration Rate (%)', 'Consumer Trust in AI (%)', 'Market Share of AI Companies (%)']
# cat_features.... ['Country', 'Industry', 'Top AI Tools Used', 'Regulation Status']

# %% [markdown]
# # Apply LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()

for col in df.columns:
  if df[col].dtype == 'object':
    df[col] = lb.fit_transform(df[col])

df.head()
# Out:
#    Country  Year  Industry  AI Adoption Rate (%)  \
# 0        7  2022         8                 44.29
# 1        2  2025         5                 34.75
# 2        9  2022         0                 81.06
# 3        3  2021         5                 85.24
# 4        3  2021         3                 78.95
#
#    AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                       33.09                   16.77
# 1                                       66.74                   46.89
# 2                                       96.13                   10.66
# 3                                       93.76                   27.70
# 4                                       45.62                   17.45
#
#    Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                           46.12                            74.79
# 1                           52.46                            26.17
# ...

# %% [markdown]
# # Spliting the Data

# %%
df = df.drop(columns = 'Country')

x = df.drop(columns=['Industry'])
y = df['Industry']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
np.round(x_train.describe(),2)
# Out:
#           Year  AI Adoption Rate (%)  \
# count   160.00                160.00
# mean   2022.35                 55.03
# std       1.83                 23.90
# min    2020.00                 10.53
# 25%    2021.00                 33.74
# 50%    2022.00                 56.06
# 75%    2024.00                 76.25
# max    2025.00                 94.76
#
#        AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# count                                      160.00                  160.00
# mean                                        47.37                   25.32
# std                                         29.65                   13.44
# min                                          1.04                    0.09
# 25%                                         20.32                   15.21
# 50%                                         47.16                   25.48
# 75%                                         74.01                   36.81
# ...

# %% [markdown]
# # Handeling Missing Data

# %%
from sklearn.impute import SimpleImputer

for col in df.columns:
  if df[col].dtype == 'object':

    si = SimpleImputer('most_frequent')
    df[col] = si.fit_transform(df[[col]])

  else:

    si = SimpleImputer(strategy='mean')
    df[col] = si.fit_transform(df[[col]])

# %% [markdown]
# # Apply Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train_sc = sc.fit_transform(x_train)

x_train_new = pd.DataFrame(x_train_sc, columns = x_train.columns)

np.round(x_train_new.describe(),2)
# Out:
#          Year  AI Adoption Rate (%)  \
# count  160.00                160.00
# mean     0.00                 -0.00
# std      1.00                  1.00
# min     -1.29                 -1.87
# 25%     -0.74                 -0.89
# 50%     -0.19                  0.04
# 75%      0.90                  0.89
# max      1.45                  1.67
#
#        AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# count                                      160.00                  160.00
# mean                                         0.00                   -0.00
# std                                          1.00                    1.00
# min                                         -1.57                   -1.88
# 25%                                         -0.92                   -0.75
# 50%                                         -0.01                    0.01
# 75%                                          0.90                    0.86
# ...

# %% [markdown]
# # Apply Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

mn = MinMaxScaler()

x_train_mn = mn.fit_transform(x_train)

x_train_new = pd.DataFrame(x_train_mn,columns = x_train.columns)

np.round(x_train_new.describe(),2)
# Out:
#          Year  AI Adoption Rate (%)  \
# count  160.00                160.00
# mean     0.47                  0.53
# std      0.37                  0.28
# min      0.00                  0.00
# 25%      0.20                  0.28
# 50%      0.40                  0.54
# 75%      0.80                  0.78
# max      1.00                  1.00
#
#        AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# count                                      160.00                  160.00
# mean                                         0.47                    0.51
# std                                          0.30                    0.27
# min                                          0.00                    0.00
# 25%                                          0.20                    0.30
# 50%                                          0.47                    0.51
# 75%                                          0.74                    0.74
# ...

# %% [markdown]
# # Column-Transformer and Pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Identify categorical and numeric columns from x_train
categorical_cols = x_train.select_dtypes(include=['object']).columns
numeric_cols = x_train.select_dtypes(include=['int64', 'float64']).columns

# Preprocessing for numeric data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Column transformer
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_cols),
    ('cat', categorical_transformer, categorical_cols)
])

# Final pipeline with logistic regression
clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

# Fit the pipeline
clf.fit(x_train, y_train)

# Predict
y_pred = clf.predict(x_test)

print('accuracy', accuracy_score(y_test, y_pred))
# Out:
# accuracy 0.075

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# 0.075

# %% [markdown]
# # Decision Tree Classifiers

# %%
from sklearn.tree import DecisionTreeClassifier

lr = DecisionTreeClassifier()

lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.15

# %% [markdown]
# # Random Forest Classifier and Fine-Tuning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier(random_state=42)

# hyperparameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# Perform Grid Search with Cross-Validation
clf = GridSearchCV(estimator = rf, param_grid = param_grid, cv=5, verbose=1, n_jobs=-1)

# Fit the model
best_clf = clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# Get the best estimator (best combination of hyperparameters)
print("Best Parameters:", best_clf.best_params_)
print("Best Estimator:", best_clf.best_estimator_)

print('accuracy', accuracy_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Best Estimator: RandomForestClassifier(max_depth=10, min_samples_leaf=2, random_state=42)
# accuracy 0.075
